# %% [markdown]
# ## Use barcharts and heatmaps to visualize patterns in your data
# IGN Game Reviews provide scores from experts for the most recent game releases, ranging from 0 (Disaster) to 10 (Masterpiece).
# <img src="https://i.imgur.com/Oh06Fu1.png">

# %% [markdown]
# ## Load the data
# 1. Read the IGN data file into a dataframe named `ign_scores`.
# 2. Use the `"Platform"` column to label the rows.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

IGN="https://raw.githubusercontent.com/csbfx/advpy122-data/master/ign_scores.csv"
## Your code here . . .
ign_scores = pd.read_csv(IGN)
ign_scores.set_index("Platform", inplace=True)

# %% [markdown]
# ## Problem 1
# Use the dataframe ign_scores and write one line of code to determine the highest score received by any kind of games on the Wii platform?

# %%
## Your code here
ign_scores.loc["Wii"].max()
# Out:
# 7.410344827586206

# %% [markdown]
# ## Problem 2
# Use the dataframe `ign_scores` to determine which genre has the lowest score for the `PlayStation Vita` platform.

# %%
## Your code here
ign_scores.loc["PlayStation Vita"].sort_values(ascending=True)
# Out:
# Simulation           5.725000
# Action, Adventure    6.133333
# Racing               6.300000
# Sports               7.130000
# Action               7.173077
# RPG                  7.337500
# Fighting             7.527273
# Shooter              7.660000
# Adventure            8.057143
# Puzzle               8.250000
# Platformer           8.568750
# Strategy             8.900000
# Name: PlayStation Vita, dtype: float64

# %% [markdown]
# ## Problem 3
# Your instructor's favorite video game has been Mario Kart Wii, a racing game released for the Wii platform in 2008. And, IGN agrees with her that it is a great game -- their rating for this game is a whopping 8.9! Inspired by the success of this game, your instructor is considering creating your very own racing game for the Wii platform. Perform the following analyses to help her determine which platform she should focus on.
#
# 1. Create a bar chart that shows the score for *Racing* games, for each platform. Your chart should have one bar for each platform. Provide a meaningful title to the plot.
#
# 2. Based on the bar chart, do you expect a racing game for the **Wii** platform to receive a high rating?  If not, use the pandas to find out from the dataframe `ign_scores` which gaming platform is the best for racing game?

# %%
# Set the width and height of the figure
# Your code here . . .

# Figure and axes variables are defined for further customization
fig, ax = plt.subplots(figsize=(20,6))

sns.barplot(
    data=ign_scores,
    x="Platform",
    y="Racing"
)

ax.tick_params('x', labelrotation=45)

plt.title("Mean of Highest Racing Scores for Each Platform")
plt.show();

# %%
## Use ign_scores to determine which gaming platform is the best
## for racing game.

## Your code here . . .
ign_scores.Racing.sort_values(ascending=False)
# Out:
# Platform
# Xbox One                8.163636
# PlayStation 4           7.590000
# iPhone                  7.315789
# Dreamcast               7.042500
# PC                      7.032418
# Xbox                    7.021591
# Xbox 360                6.996154
# PlayStation 3           6.978571
# Nintendo 64             6.939623
# Nintendo 3DS            6.900000
# Wireless                6.898305
# GameCube                6.852632
# PlayStation             6.773387
# Game Boy Advance        6.657143
# PlayStation 2           6.585065
# Nintendo DSi            6.563636
# PlayStation Portable    6.401961
# PlayStation Vita        6.300000
# Nintendo DS             6.038636
# Game Boy Color          5.897436
# Wii                     5.011667
# Name: Racing, dtype: float64

# %% [markdown]
# #### Problem 4
# Since your instructor's gaming interests are pretty broad, you can help her decide to use the IGN scores to determine the choice of genre and platform.
#
# 1. Create a heatmap using the IGN scores by genre and platform and include the scores in the cells of the heatmap.
# 2. Base on the heatmap, which combination of genre and platform receives the highest average ratings?  Which combination receives the lowest average rankings? Write the answers in a markdown cell.

# %%
## Create a heatmap
# Your code here . . .
fig, ax = plt.subplots(figsize=(10,10))

sns.heatmap(
    data=ign_scores,
    annot=True,
    square=True,
    cmap='magma'
)

plt.title("Heatmap of Game Genres and Game Platforms")
# Out:
# Text(0.5, 1.0, 'Heatmap of Game Genres and Game Platforms')

# %% [markdown]
# #### Problem 4 Answer
# The combination of genre and platform with the highest average ratings is the Simulation genre and the PlayStation 4.
#
# On the other hand, the combination of genre and platform with the lowest average ratings is a tie between the Shooter and Fighting genres and the Game Boy Color.

# %% [markdown]
# ## Problem 5
# Use the Pokemon dataset to create a clustermap with color. First, filter the dataframe to only keep data with `Type 1` equals to following values: `Water`, `Normal`, `Grass`, `Bug` and `Psychic`. Annotate the dendrogram using different colors for these five different `Type 1` values. Use `Name` as the index.
#
# pokemon_data is in https://raw.githubusercontent.com/csbfx/advpy122-data/master/Pokemon.csv

# %%
# Problem 5
# Your code here . . .
pokemon_data = "https://raw.githubusercontent.com/csbfx/advpy122-data/master/Pokemon.csv"
pokedex = pd.read_csv(pokemon_data)

# %%
pokedex.info()
pokedex.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
# Filter the PokeDex to keep Type 1 Pokemon that are Water, Normal, Grass, Bug, and Psychic
pokedex_t1 = pokedex[
    (pokedex['Type 1'] == "Water") |
    (pokedex['Type 1'] == "Normal") |
    (pokedex['Type 1'] == "Grass") |
    (pokedex['Type 1'] == "Bug") |
    (pokedex['Type 1'] == "Psychic")
]

pokedex_t1.set_index("Name", inplace=True)

colors = {
    "Water" : "blue",
    "Normal" : "grey",
    "Grass" : "green",
    "Bug" : "orange",
    "Psychic" : "purple"
}

row_colors = pokedex_t1['Type 1'].map(colors)

num_cols = ["Total", "HP", "Attack", "Defense", "Sp. Atk", "Sp. Def", "Speed", "Generation"]

# Drop non-numerical columns to render the cluster map
pokedex_t1 = pokedex_t1[num_cols]

sns.clustermap(
    data=pokedex_t1,
    row_colors=row_colors,
    figsize=(12, 10),
    cmap='mako'
)
